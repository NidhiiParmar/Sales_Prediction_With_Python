# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiiParmar/Sales_Prediction_With_Python/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK_5  Sales Prediction**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/Advertising (1).csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Display the first few rows of the DataFrame
df.head(5)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Display the last few rows of the DataFrame
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
# Check the size of the DataFrame (number of elements)
df.size
# Out:
# 1000

# %%
# Get information about the DataFrame (data types, memory usage, etc.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# Get the shape of the DataFrame (number of rows and columns)
df.shape
# Out:
# (200, 5)

# %%
 # Generate descriptive statistics of the numerical columns
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
# Display the column names of the DataFrame
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# Print specific columns of the DataFrame
print(df[['TV','Newspaper']])
# Out:
#         TV  Newspaper
# 0    230.1       69.2
# 1     44.5       45.1
# 2     17.2       69.3
# 3    151.5       58.5
# 4    180.8       58.4
# ..     ...        ...
# 195   38.2       13.8
# 196   94.2        8.1
# 197  177.0        6.4
# 198  283.6       66.2
# 199  232.1        8.7
#
# [200 rows x 2 columns]

# %%
# Display the indexes of the DataFrame
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
#Check for duplicate values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Checking for null values
df.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
# Create a heatmap to visualize the correlation between features
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# Create histograms for numerical columns in the DataFrame
df.plot.hist()
plt.show()

# %%
px.scatter(df,x='TV',y='Sales',width=500,height=500,title='Sales Vs TV')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x='Radio',y='Sales',width=500,height=500,title='Sales Vs Radio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x='Newspaper',y='Sales',width=800,height=500,title='Sales Vs Newspaper')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['TV']=df['TV'].astype('int')
df['Radio']=df['Radio'].astype('int')
df['Newspaper']=df['Newspaper'].astype('int')
df['Sales']=df['Sales'].astype('int')
df
# Out:
#      Unnamed: 0   TV  Radio  Newspaper  Sales
# 0             1  230     37         69     22
# 1             2   44     39         45     10
# 2             3   17     45         69      9
# 3             4  151     41         58     18
# 4             5  180     10         58     12
# ..          ...  ...    ...        ...    ...
# 195         196   38      3         13      7
# 196         197   94      4          8      9
# 197         198  177      9          6     12
# 198         199  283     42         66     25
# 199         200  232      8          8     13
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
x=df.drop('Sales',axis=1)
x
# Out:
#      Unnamed: 0   TV  Radio  Newspaper
# 0             1  230     37         69
# 1             2   44     39         45
# 2             3   17     45         69
# 3             4  151     41         58
# 4             5  180     10         58
# ..          ...  ...    ...        ...
# 195         196   38      3         13
# 196         197   94      4          8
# 197         198  177      9          6
# 198         199  283     42         66
# 199         200  232      8          8
#
# [200 rows x 4 columns]

# %%
x = x.drop(columns='Unnamed: 0')
x
# Out:
#       TV  Radio  Newspaper
# 0    230     37         69
# 1     44     39         45
# 2     17     45         69
# 3    151     41         58
# 4    180     10         58
# ..   ...    ...        ...
# 195   38      3         13
# 196   94      4          8
# 197  177      9          6
# 198  283     42         66
# 199  232      8          8
#
# [200 rows x 3 columns]

# %%
y=df[['Sales']]
y
# Out:
#      Sales
# 0       22
# 1       10
# 2        9
# 3       18
# 4       12
# ..     ...
# 195      7
# 196      9
# 197     12
# 198     25
# 199     13
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size = 0.20, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
# creating a Linear regression object
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
coefficients = lr.coef_[0]
coefficients_df = pd.DataFrame({'Feature': ['TV', 'Newspaper', 'Radio'], 'Coefficient': coefficients})

print(coefficients_df)
# Out:
#      Feature  Coefficient
# 0         TV     0.044561
# 1  Newspaper     0.199364
# 2      Radio    -0.002078

# %%
lr.intercept_
# Out:
# array([2.54660057])

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 9.5712015 ],
#        [ 6.93026051],
#        [ 6.50931532],
#        [23.69210929],
#        [11.4448268 ],
#        [ 5.97858277],
#        [12.31669692],
#        [14.62022924],
#        [10.41416563],
#        [15.88145011],
#        [22.43815877],
#        [ 8.56447987],
#        [ 9.88026165],
#        [15.04750051],
#        [11.07100187],
#        [11.65901033],
#        [18.34262032],
#        [10.30517367],
#        [15.51945314],
#        [16.79587287],
#        [23.76078554],
#        [ 8.96583889],
#        [14.66640747],
#        [11.90202021],
#        [ 5.26343281],
#        [14.78107713],
#        [11.85752142],
#        [20.61355881],
#        [12.89588056],
#        [ 8.55536917],
#        [12.47239091],
#        [21.01387738],
#        [17.53859511],
#        [20.81390311],
#        [ 6.01452345],
#        [ 5.69327245],
#        [ 7.47871948],
#        [12.44073173],
#        [14.27604771],
#        [ 5.79336771]])

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_pred,y_test))
# Out:
# Mean Absolute Error:  1.3525884067006586

# %%
print('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
# Out:
# Root Mean Squared Error: 2.089098453853483

# %%
print('R-Squared: ',metrics.r2_score(y_pred,y_test))
# Out:
# R-Squared:  0.8367647885536234
